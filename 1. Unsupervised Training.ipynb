# %% [markdown]
# # 1. Training Unsupervised SentenceTransformer

# %%
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm

from sentence_transformers import SentenceTransformer, models, InputExample, losses
from sentence_transformers import evaluation

from datasets import Dataset
from torch.utils.data import DataLoader

# Custom libraries
from utils.unsupervised_utils import generate_topic_model_input, generate_content_model_input, read_data
from utils.utils import read_config

# %%
config = read_config()

# %%
DATA_PATH = "../raw_data/"

# %%
topics, content, correlations = read_data(data_path=DATA_PATH,
                                          config_obj=config,
                                          read_mode="train")
# Out:
#
# --------------------------------------------------
# topics.shape: (55266, 4)
# content.shape: (154047, 3)
# correlations.shape: (61517, 2)

# %%
topics.rename(columns=lambda x: "topic_" + x, inplace=True)
content.rename(columns=lambda x: "content_" + x, inplace=True)

# %%
content.head(3)
# Out:
#        content_id content_title  \
# 0  c_77105b4b84cc
# 1  c_77574ef20c1f
# 2  c_200ae87baf4d
#
#                                  content_model_input
# 0  Un espíritu revestido de piel humana Un espíri...
# 1  Recurso Educativo Abierto para Ciencias Natura...
# 2  Recurso Educativo Abierto para Geografía e His...

# %%
topics.head(3)
# Out:
#          topic_id topic_title  \
# 0  t_3d9ad9931021
# 1  t_59bf60f88801           R
# 2  t_70e95cceae67          巧算
#
#                                     topic_topic_tree  \
# 0  Libretext Open Educational Resource Library > ...
# 1                          Goalkicker Tech Books > R
# 2    Khan Academy (中国大陆) > 数学 > 三年级 > 除数是一位数的除法 > 巧算
#
#                                    topic_model_input
# 0  en 3 [SEP] BC: BIOL 2 - Introduction to Human ...
# 1  en 1 [SEP] R A book about R exported from the ...
# 2  zh 4 [SEP] 巧算 用多种方法计算除数是一位数的除法 Khan Academy (中...

# %%
correlations["content_id"] = correlations["content_ids"].str.split(" ")
corr = correlations.explode("content_id").drop(columns=["content_ids"])
corr.head(3)
# Out:
#          topic_id      content_id
# 0  t_00004da3a1b2  c_1108dd0c7a5d
# 0  t_00004da3a1b2  c_376c5a8eb028
# 0  t_00004da3a1b2  c_5bc0e1e2cba0

# %%
corr = corr.merge(topics, how="left", on="topic_id")
corr = corr.merge(content, how="left", on="content_id")
corr.head(3)
# Out:
#          topic_id      content_id                 topic_title  \
# 0  t_00004da3a1b2  c_1108dd0c7a5d  Откриването на резисторите
# 1  t_00004da3a1b2  c_376c5a8eb028  Откриването на резисторите
# 2  t_00004da3a1b2  c_5bc0e1e2cba0  Откриването на резисторите
#
#                                     topic_topic_tree  \
# 0  Khan Academy (български език) > Наука > Физика...
# 1  Khan Academy (български език) > Наука > Физика...
# 2  Khan Academy (български език) > Наука > Физика...
#
#                                    topic_model_input  \
# 0  bg 4 [SEP] Откриването на резисторите Изследва...
# 1  bg 4 [SEP] Откриването на резисторите Изследва...
# 2  bg 4 [SEP] Откриването на резисторите Изследва...
#
#                                     content_title  \
# 0                             Молив като резистор
# 1              Да чуем променливото съпротивление
# 2  Променлив резистор (реостат) с графит от молив
#
#                                  content_model_input
# 0  Молив като резистор Моливът причинява промяна ...
# 1  Да чуем променливото съпротивление Тук чертаем...
# 2  Променлив резистор (реостат) с графит от молив...

# %%
corr["set"] = corr[["topic_model_input", "content_model_input"]].values.tolist()
train_df = pd.DataFrame(corr["set"])

# %%
train_df.head(3)
# Out:
#                                                  set
# 0  [bg 4 [SEP] Откриването на резисторите Изследв...
# 1  [bg 4 [SEP] Откриването на резисторите Изследв...
# 2  [bg 4 [SEP] Откриването на резисторите Изследв...

# %%
dataset = Dataset.from_pandas(train_df)
dataset
# Out:
# Dataset({
#     features: ['set', '__index_level_0__'],
#     num_rows: 279919
# })

# %%
train_examples = []
train_data = dataset["set"]
n_examples = dataset.num_rows

for i in range(n_examples):
    example = train_data[i]
    if example[0] == None:
        continue        
    train_examples.append(InputExample(texts=[str(example[0]), str(example[1])]))

# %% [markdown]
# ### Training

# %%
TARGET_MODEL = config["unsupervised_model"]["base_name"]
OUT_MODEL = config["unsupervised_model"]["save_name"]
TARGET_MODEL, OUT_MODEL
# Out:
# ('sentence-transformers/all-MiniLM-L6-v2',
#  'trained_models/unsupervised/all-MiniLM-L6-v2')

# %%
model = SentenceTransformer(TARGET_MODEL)
model.max_seq_length = config["unsupervised_model"]["seq_len"]

word_embedding_model = model._first_module()
tokens = ["[SEP]"]
word_embedding_model.tokenizer.add_tokens(tokens, special_tokens=True)
word_embedding_model.auto_model.resize_token_embeddings(len(word_embedding_model.tokenizer))
# Out:
# Embedding(30522, 384, padding_idx=0)

# %%
train_dataloader = DataLoader(train_examples,
                              shuffle=True,
                              batch_size=config["unsupervised_model"]["batch_size"])

train_loss = losses.MultipleNegativesRankingLoss(model=model)

#k% of train data
num_epochs = config["unsupervised_model"]["epochs"]
warmup_steps = int(len(train_dataloader) * num_epochs * config["unsupervised_model"]["warmup_ratio"])

# %%
model.fit(train_objectives=[(train_dataloader, train_loss)],
          epochs=num_epochs,
          warmup_steps=warmup_steps,
         use_amp=True)
# Out:
# Epoch:   0%|          | 0/2 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/850 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/850 [00:00<?, ?it/s]

# %%
model.save(OUT_MODEL)
